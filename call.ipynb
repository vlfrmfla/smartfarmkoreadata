# %%
import requests
import json
import os
from dotenv import load_dotenv
from urllib.parse import quote

# .env에서 API 키 불러오기
load_dotenv()
service_key = quote(os.getenv("SMARTFARM_API_KEY").strip(), safe='')

# 저장 경로
SAVE_PATH = "identity_data.json"

def get_identity_data_list():
    url = f"http://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getIdentityDataList/{service_key}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()

        # JSON 파일로 저장
        with open(SAVE_PATH, "w", encoding="utf-8") as f:
            json.dump(data, f, ensure_ascii=False, indent=2)

        print(f"농가 정보가 '{SAVE_PATH}'에 저장되었습니다.")
        return data
    except Exception as e:
        print(f"API 요청 실패: {e}")
        return None

def get_cropping_season_data_list(service_key, user_id):
    encoded_key = quote(service_key, safe='')
    url = f"http://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getCroppingSeasonDataList/{encoded_key}/{user_id}"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        print(f"작기 정보 요청 실패: {e}")
        return None
    
def load_identity_data(filepath="identity_data.json"):
    try:
        with open(filepath, "r", encoding="utf-8") as f:
            return json.load(f)
    except Exception as e:
        print(f"파일 로딩 실패: {e}")
        return None
    
def get_cultivate_data_safe(args):
    user_id, serl_no, start, end = args
    url = f"http://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getCultivateDataList/{service_key}/{user_id}/{serl_no}/{start}/{end}"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()

        # ✅ statusCode가 "00"인 항목이 1개라도 있어야 유효
        if isinstance(data, list) and any(d.get("statusCode") == "00" for d in data):
            return {
                "userId": user_id,
                "croppingSerlNo": serl_no,
                "startDate": start,
                "endDate": end,
                "cultivateData": data
            }

    except Exception as e:
        print(f"❌ 실패: {user_id}, {serl_no} - {e}")
    return None

# %%
# 농가 목록을 조회하고 파일로 저장
if __name__ == "__main__":
    get_identity_data_list()
# Out:
# ✅ 농가 정보가 'identity_data.json'에 저장되었습니다.

# %%
## 토마토 작기 정보 operation 후 저장 (save file: tomato_cropping_data.json)

all_cropping_data = []

if __name__ == "__main__":
    identity_data = load_identity_data()

    if identity_data:
        tomato_farms = [entry for entry in identity_data if entry.get("itemCode") == "080300"] ## tomato key 080300
        print(f"토마토 농가 수: {len(tomato_farms)}")

        for farm in tomato_farms:
            user_id = farm.get("userId")
            print(f"\n userId: {user_id} - 작기 정보 조회 중...")
            cropping_data = get_cropping_season_data_list(service_key, user_id)

            if cropping_data:
                all_cropping_data.append({
                    "userId": user_id,
                    "croppingData": cropping_data
                })
    else:
        print("농가 정보를 불러오지 못했습니다.")

with open("tomato_cropping_data.json", "w", encoding="utf-8") as f:
    json.dump(all_cropping_data, f, ensure_ascii=False, indent=2)
# Out:
# 🍅 토마토 농가 수: 355
#
# 📦 userId: PFS_0000001 - 작기 정보 조회 중...
#
# 📦 userId: PFS_0000002 - 작기 정보 조회 중...
#
# 📦 userId: PFS_0000003 - 작기 정보 조회 중...
#
# 📦 userId: PFS_0000004 - 작기 정보 조회 중...
#
# 📦 userId: PFS_0000006 - 작기 정보 조회 중...
#
# 📦 userId: PFS_0000007 - 작기 정보 조회 중...
#
# 📦 userId: PFS_0000008 - 작기 정보 조회 중...
#
# 📦 userId: PFS_0000009 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000002 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000004 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000005 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000006 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000007 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000008 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000009 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000010 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000011 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000012 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000013 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000014 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000015 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000016 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000017 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000018 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000019 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000020 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000034 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000039 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000040 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000042 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000043 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000047 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000099 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000116 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000125 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000185 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000192 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000227 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000243 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000265 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000279 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000304 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000365 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000594 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000806 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000842 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000844 - 작기 정보 조회 중...
#
# 📦 userId: PF_0001001 - 작기 정보 조회 중...
#
# 📦 userId: PF_0001002 - 작기 정보 조회 중...
#
# 📦 userId: PF_0001009 - 작기 정보 조회 중...
#
# 📦 userId: PF_0001402 - 작기 정보 조회 중...
#
# 📦 userId: PF_0001405 - 작기 정보 조회 중...
#
# 📦 userId: PF_0001406 - 작기 정보 조회 중...
#
# 📦 userId: PF_0001412 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002525 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002526 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002527 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002528 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002529 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002531 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002532 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002547 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002548 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002551 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002904 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006023 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006024 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006025 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006042 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006043 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006044 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006045 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006046 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006047 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006404 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006412 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006414 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006415 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010009 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010013 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010014 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010015 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010016 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010017 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010018 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010019 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010020 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010022 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010054 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010056 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010057 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010059 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010066 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010068 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010071 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010075 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010076 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020032 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020074 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020076 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020209 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020353 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020356 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020561 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020671 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020701 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020703 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020724 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020725 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020726 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020738 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020745 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020748 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020749 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020758 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020760 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020761 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020763 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020764 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020968 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020974 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021193 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021196 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021197 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021199 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021200 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021229 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021230 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021231 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021232 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021233 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021234 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021235 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021236 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021237 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021238 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021239 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021240 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021241 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021242 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021244 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021245 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021246 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021247 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021248 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021249 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021250 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021251 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021252 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021253 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021254 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021255 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021256 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021257 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021258 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021259 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021260 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021261 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021262 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021263 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021264 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021265 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021266 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021267 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021268 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021269 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021270 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021271 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021272 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021273 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022077 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022078 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022079 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022080 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022081 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022082 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022083 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022084 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022085 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022092 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022094 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022097 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022098 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022100 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022101 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022102 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022109 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022116 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022117 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022120 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022121 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022122 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022125 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022127 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022161 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022235 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022374 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022376 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023488 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023490 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023494 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023495 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023505 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023513 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023521 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023609 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023610 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023611 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023612 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023613 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023615 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023616 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023617 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023618 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023619 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023623 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023624 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023625 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023626 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023627 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024001 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024003 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024240 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024241 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024242 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024243 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024244 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024245 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024246 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024247 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024248 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024249 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024250 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024251 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024252 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024253 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024377 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024541 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024656 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024689 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024693 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024696 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024697 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024698 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024858 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024859 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024860 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024861 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024862 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024863 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024864 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024865 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024866 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024867 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024868 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024869 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024870 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024871 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024872 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024873 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024874 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024875 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024876 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024877 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024878 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024879 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024880 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024881 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024882 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024883 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024884 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024885 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024886 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024887 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024888 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024889 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024890 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024891 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024892 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024893 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024894 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024895 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024896 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024897 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024898 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024899 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024900 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024901 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024902 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024903 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024904 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024905 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024906 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024907 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024908 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024909 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024910 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024911 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024912 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024913 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024914 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024915 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024916 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024917 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024918 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024919 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024920 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024921 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024922 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024923 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024924 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024925 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024926 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024927 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024928 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024929 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024930 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025101 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025108 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025286 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025290 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025291 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025292 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025293 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025294 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025295 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025296 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025297 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025298 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025299 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025300 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025301 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025302 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025303 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025304 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025305 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025306 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025307 - 작기 정보 조회 중...
#
# 📦 userId: sk0015 - 작기 정보 조회 중...
#
# 📦 userId: sk0019 - 작기 정보 조회 중...
#
# 📦 userId: sk0023 - 작기 정보 조회 중...
#
# 📦 userId: sk0026 - 작기 정보 조회 중...
#
# 📦 userId: sk0047 - 작기 정보 조회 중...
#
# 📦 userId: sk0057 - 작기 정보 조회 중...
#
# 📦 userId: sk0058 - 작기 정보 조회 중...
#
# 📦 userId: sk0063 - 작기 정보 조회 중...
#
# 📦 userId: sk0065 - 작기 정보 조회 중...
#
# 📦 userId: sk0073 - 작기 정보 조회 중...
#
# 📦 userId: sk0078 - 작기 정보 조회 중...
#
# 📦 userId: sk0081 - 작기 정보 조회 중...
#
# 📦 userId: sk0085 - 작기 정보 조회 중...
#
# 📦 userId: sk0091 - 작기 정보 조회 중...
#
# 📦 userId: sk0102 - 작기 정보 조회 중...
#
# 📦 userId: sk0104 - 작기 정보 조회 중...
#
# 📦 userId: sk0118 - 작기 정보 조회 중...

# %%
#check data
user_id = "PFS_0000001"             # 예시: 실제 userId
cropping_serl_no = 79               # 작기 일련번호
start_date = "2015-09-02"          # 작기 시작일
end_date = "2016-12-31"            # 작기 종료일

# user_id = "PFS_0000008"             # 예시: 실제 userId # 데이터 없는 경우  "statusMessage": "NODATA_ERROR",
# cropping_serl_no = 77               # 작기 일련번호
# start_date = "2015-07-29"          # 작기 시작일
# end_date = "2016-12-31"            # 작기 종료일

# URL 구성
url = f"http://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getCultivateDataList/{service_key}/{user_id}/{cropping_serl_no}/{start_date}/{end_date}"

# 요청 및 출력
try:
    response = requests.get(url, timeout=10)
    response.raise_for_status()
    data = response.json()
    if data:
        print("✅ 생육 데이터 존재:")
        print(json.dumps(data, indent=2, ensure_ascii=False))
    else:
        print("🚫 생육 데이터 없음")
except Exception as e:
    print(f"❌ 요청 실패: {e}")
# Out:
# ✅ 생육 데이터 존재:
# [
#   {
#     "statusCode": "00",
#     "statusMessage": "NORMAL_CODE",
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-09-06",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 0.0,
#     "fruitsPosition": 0.0,
#     "fruitsNum": 0.0,
#     "harvestPosition": 0.0,
#     "ped": 5451.0,
#     "solarCorrection": 1716.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-09-13",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 455.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4092.0,
#     "solarCorrection": 3624.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-09-20",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 448.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3654.0,
#     "solarCorrection": 6744.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-09-27",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 16.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4674.0,
#     "solarCorrection": 5565.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-10-04",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 16.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 2283.0,
#     "solarCorrection": 2718.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-10-11",
#     "growLength": 240.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.9,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 1251.0,
#     "solarCorrection": 5604.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-10-18",
#     "growLength": 230.0,
#     "flowerTop": 250.0,
#     "stemDiameter": 15.5,
#     "leavesLength": 470.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 825.0,
#     "solarCorrection": 5409.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-10-25",
#     "growLength": 210.0,
#     "flowerTop": 260.0,
#     "stemDiameter": 14.3,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 24.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3978.0,
#     "solarCorrection": 1719.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-11-01",
#     "growLength": 230.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.8,
#     "leavesLength": 460.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4554.0,
#     "solarCorrection": 5694.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-11-08",
#     "growLength": 220.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 23.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2619.0,
#     "solarCorrection": 2223.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-11-15",
#     "growLength": 210.0,
#     "flowerTop": 230.0,
#     "stemDiameter": 12.6,
#     "leavesLength": 450.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4749.0,
#     "solarCorrection": 1524.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-11-22",
#     "growLength": 180.0,
#     "flowerTop": 220.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 7164.0,
#     "solarCorrection": 5304.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-11-29",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.4,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 768.0,
#     "solarCorrection": 7200.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-12-06",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 741.0,
#     "solarCorrection": 765.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-12-13",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.2,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2799.0,
#     "solarCorrection": 6375.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-12-20",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 480.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2751.0,
#     "solarCorrection": 6402.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-12-27",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 759.0,
#     "solarCorrection": 7173.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-01-03",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-01-10",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-01-17",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 390.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-01-24",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 439.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-01-31",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-02-07",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-02-14",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-02-21",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-02-28",
#     "growLength": 200.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-03-06",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-03-13",
#     "growLength": 200.0,
#     "flowerTop": 190.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-03-20",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-03-27",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-09-06",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 0.0,
#     "fruitsPosition": 0.0,
#     "fruitsNum": 0.0,
#     "harvestPosition": 0.0,
#     "ped": 5451.0,
#     "solarCorrection": 1716.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-09-13",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 455.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4092.0,
#     "solarCorrection": 3624.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-09-20",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 448.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3654.0,
#     "solarCorrection": 6744.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-09-27",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 16.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4674.0,
#     "solarCorrection": 5565.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-10-04",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 16.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 2283.0,
#     "solarCorrection": 2718.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-10-11",
#     "growLength": 240.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.9,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 1251.0,
#     "solarCorrection": 5604.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-10-18",
#     "growLength": 230.0,
#     "flowerTop": 250.0,
#     "stemDiameter": 15.5,
#     "leavesLength": 470.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 825.0,
#     "solarCorrection": 5409.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-10-25",
#     "growLength": 210.0,
#     "flowerTop": 260.0,
#     "stemDiameter": 14.3,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 24.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3978.0,
#     "solarCorrection": 1719.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-11-01",
#     "growLength": 230.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.8,
#     "leavesLength": 460.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4554.0,
#     "solarCorrection": 5694.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-11-08",
#     "growLength": 220.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 23.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2619.0,
#     "solarCorrection": 2223.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-11-15",
#     "growLength": 210.0,
#     "flowerTop": 230.0,
#     "stemDiameter": 12.6,
#     "leavesLength": 450.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4749.0,
#     "solarCorrection": 1524.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-11-22",
#     "growLength": 180.0,
#     "flowerTop": 220.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 7164.0,
#     "solarCorrection": 5304.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-11-29",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.4,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 768.0,
#     "solarCorrection": 7200.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-12-06",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 741.0,
#     "solarCorrection": 765.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-12-13",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.2,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2799.0,
#     "solarCorrection": 6375.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-12-20",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 480.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2751.0,
#     "solarCorrection": 6402.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-12-27",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 759.0,
#     "solarCorrection": 7173.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-01-03",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-01-10",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-01-17",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 390.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-01-24",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 439.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-01-31",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-02-07",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-02-14",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-02-21",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-02-28",
#     "growLength": 200.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-03-06",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-03-13",
#     "growLength": 200.0,
#     "flowerTop": 190.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-03-20",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-03-27",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-09-06",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 0.0,
#     "fruitsPosition": 0.0,
#     "fruitsNum": 0.0,
#     "harvestPosition": 0.0,
#     "ped": 5451.0,
#     "solarCorrection": 1716.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-09-13",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 455.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4092.0,
#     "solarCorrection": 3624.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-09-20",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 448.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3654.0,
#     "solarCorrection": 6744.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-09-27",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 16.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4674.0,
#     "solarCorrection": 5565.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-10-04",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 16.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 2283.0,
#     "solarCorrection": 2718.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-10-11",
#     "growLength": 240.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.9,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 1251.0,
#     "solarCorrection": 5604.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-10-18",
#     "growLength": 230.0,
#     "flowerTop": 250.0,
#     "stemDiameter": 15.5,
#     "leavesLength": 470.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 825.0,
#     "solarCorrection": 5409.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-10-25",
#     "growLength": 210.0,
#     "flowerTop": 260.0,
#     "stemDiameter": 14.3,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 24.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3978.0,
#     "solarCorrection": 1719.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-11-01",
#     "growLength": 230.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.8,
#     "leavesLength": 460.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4554.0,
#     "solarCorrection": 5694.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-11-08",
#     "growLength": 220.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 23.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2619.0,
#     "solarCorrection": 2223.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-11-15",
#     "growLength": 210.0,
#     "flowerTop": 230.0,
#     "stemDiameter": 12.6,
#     "leavesLength": 450.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4749.0,
#     "solarCorrection": 1524.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-11-22",
#     "growLength": 180.0,
#     "flowerTop": 220.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 7164.0,
#     "solarCorrection": 5304.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-11-29",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.4,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 768.0,
#     "solarCorrection": 7200.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-12-06",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 741.0,
#     "solarCorrection": 765.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-12-13",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.2,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2799.0,
#     "solarCorrection": 6375.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-12-20",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 480.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2751.0,
#     "solarCorrection": 6402.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-12-27",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 759.0,
#     "solarCorrection": 7173.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-01-03",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-01-10",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-01-17",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 390.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-01-24",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 439.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-01-31",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-02-07",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-02-14",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-02-21",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-02-28",
#     "growLength": 200.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-03-06",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-03-13",
#     "growLength": 200.0,
#     "flowerTop": 190.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-03-20",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-03-27",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-09-06",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 0.0,
#     "fruitsPosition": 0.0,
#     "fruitsNum": 0.0,
#     "harvestPosition": 0.0,
#     "ped": 5451.0,
#     "solarCorrection": 1716.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-09-13",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 455.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4092.0,
#     "solarCorrection": 3624.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-09-20",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 448.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3654.0,
#     "solarCorrection": 6744.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-09-27",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 16.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4674.0,
#     "solarCorrection": 5565.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-10-04",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 16.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 2283.0,
#     "solarCorrection": 2718.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-10-11",
#     "growLength": 240.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.9,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 1251.0,
#     "solarCorrection": 5604.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-10-18",
#     "growLength": 230.0,
#     "flowerTop": 250.0,
#     "stemDiameter": 15.5,
#     "leavesLength": 470.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 825.0,
#     "solarCorrection": 5409.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-10-25",
#     "growLength": 210.0,
#     "flowerTop": 260.0,
#     "stemDiameter": 14.3,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 24.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3978.0,
#     "solarCorrection": 1719.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-11-01",
#     "growLength": 230.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.8,
#     "leavesLength": 460.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4554.0,
#     "solarCorrection": 5694.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-11-08",
#     "growLength": 220.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 23.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2619.0,
#     "solarCorrection": 2223.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-11-15",
#     "growLength": 210.0,
#     "flowerTop": 230.0,
#     "stemDiameter": 12.6,
#     "leavesLength": 450.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4749.0,
#     "solarCorrection": 1524.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-11-22",
#     "growLength": 180.0,
#     "flowerTop": 220.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 7164.0,
#     "solarCorrection": 5304.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-11-29",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.4,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 768.0,
#     "solarCorrection": 7200.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-12-06",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 741.0,
#     "solarCorrection": 765.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-12-13",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.2,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2799.0,
#     "solarCorrection": 6375.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-12-20",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 480.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2751.0,
#     "solarCorrection": 6402.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-12-27",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 759.0,
#     "solarCorrection": 7173.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-01-03",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-01-10",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-01-17",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 390.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-01-24",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 439.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-01-31",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-02-07",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-02-14",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-02-21",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-02-28",
#     "growLength": 200.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-03-06",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-03-13",
#     "growLength": 200.0,
#     "flowerTop": 190.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-03-20",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-03-27",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   }
# ]

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed

# JSON 로딩
with open("tomato_cropping_data.json", "r", encoding="utf-8") as f:
    tomato_cropping_data = json.load(f)

# 요청 목록 생성
request_args = []
for entry in tomato_cropping_data:
    user_id = entry.get("userId")
    for crop in entry.get("croppingData", []):
        serl_no = crop.get("croppingSerlNo")
        start = crop.get("croppingDate")
        end = crop.get("croppingEndDate")
        if all([user_id, serl_no, start, end]):
            request_args.append((user_id, serl_no, start, end))

# 병렬 실행
valid_entries = []
total = len(request_args)
completed = 0

with ThreadPoolExecutor(max_workers=10) as executor:
    futures = [executor.submit(get_cultivate_data, args) for args in request_args]
    for future in as_completed(futures):
        completed += 1
        result = future.result()
        if result:
            valid_entries.append(result)
            print(f"✅ {completed}/{total} | 생육 데이터 있음: userId={result['userId']} serlNo={result['croppingSerlNo']}")
        else:
            print(f"❌ {completed}/{total} | 생육 데이터 없음")

# 저장
with open("tomato_cultivate_data_valid.json", "w", encoding="utf-8") as f:
    json.dump(valid_entries, f, ensure_ascii=False, indent=2)

# 요약 출력
print(f"\n🎯 최종 요약")
print(f"✅ 생육 데이터 있는 항목: {len(valid_entries)}개")
print(f"🚫 생육 데이터 없는 항목: {total - len(valid_entries)}개")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [32], line 27
#      25 for future in as_completed(futures):
#      26     completed += 1
# ---> 27     result = future.result()
#      28     if result:
#      29         valid_entries.append(result)
#
# File ~/miniforge3/envs/torch/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniforge3/envs/torch/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/miniforge3/envs/torch/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# TypeError: get_cultivate_data() missing 4 required positional arguments: 'user_id', 'cropping_serl_no', 'start_date', and 'end_date'
