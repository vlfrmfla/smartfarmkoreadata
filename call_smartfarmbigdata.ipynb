# %%
import requests
import json
import os
from dotenv import load_dotenv
from urllib.parse import quote

# .env에서 API 키 불러오기
load_dotenv()
service_key = quote(os.getenv("SMARTFARM_API_KEY").strip(), safe='')

# 저장 경로
SAVE_PATH = "identity_data.json"

def get_identity_data_list():
    url = f"http://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getIdentityDataList/{service_key}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()

        # JSON 파일로 저장
        with open(SAVE_PATH, "w", encoding="utf-8") as f:
            json.dump(data, f, ensure_ascii=False, indent=2)

        print(f"농가 정보가 '{SAVE_PATH}'에 저장되었습니다.")
        return data
    except Exception as e:
        print(f"API 요청 실패: {e}")
        return None

def get_cropping_season_data_list(service_key, user_id):
    encoded_key = quote(service_key, safe='')
    url = f"http://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getCroppingSeasonDataList/{encoded_key}/{user_id}"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        print(f"작기 정보 요청 실패: {e}")
        return None
    
def load_identity_data(filepath="identity_data.json"):
    try:
        with open(filepath, "r", encoding="utf-8") as f:
            return json.load(f)
    except Exception as e:
        print(f"파일 로딩 실패: {e}")
        return None
    
def get_cultivate_data_safe(args):
    user_id, serl_no, start, end = args
    url = f"http://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getCultivateDataList/{service_key}/{user_id}/{serl_no}/{start}/{end}"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()

        # ✅ statusCode가 "00"인 항목이 1개라도 있어야 유효
        if isinstance(data, list) and any(d.get("statusCode") == "00" for d in data):
            return {
                "userId": user_id,
                "croppingSerlNo": serl_no,
                "startDate": start,
                "endDate": end,
                "cultivateData": data
            }

    except Exception as e:
        print(f"❌ 실패: {user_id}, {serl_no} - {e}")
    return None

# %%
# 농가 목록을 조회하고 파일로 저장
if __name__ == "__main__":
    get_identity_data_list()
# Out:
# ✅ 농가 정보가 'identity_data.json'에 저장되었습니다.

# %%
## 토마토 작기 정보 operation 후 저장 (save file: tomato_cropping_data.json)

all_cropping_data = []

if __name__ == "__main__":
    identity_data = load_identity_data()

    if identity_data:
        tomato_farms = [entry for entry in identity_data if entry.get("itemCode") == "080300"] ## tomato key 080300
        print(f"토마토 농가 수: {len(tomato_farms)}")

        for farm in tomato_farms:
            user_id = farm.get("userId")
            print(f"\n userId: {user_id} - 작기 정보 조회 중...")
            cropping_data = get_cropping_season_data_list(service_key, user_id)

            if cropping_data:
                all_cropping_data.append({
                    "userId": user_id,
                    "croppingData": cropping_data
                })
    else:
        print("농가 정보를 불러오지 못했습니다.")

with open("tomato_cropping_data.json", "w", encoding="utf-8") as f:
    json.dump(all_cropping_data, f, ensure_ascii=False, indent=2)
# Out:
# 🍅 토마토 농가 수: 355
#
# 📦 userId: PFS_0000001 - 작기 정보 조회 중...
#
# 📦 userId: PFS_0000002 - 작기 정보 조회 중...
#
# 📦 userId: PFS_0000003 - 작기 정보 조회 중...
#
# 📦 userId: PFS_0000004 - 작기 정보 조회 중...
#
# 📦 userId: PFS_0000006 - 작기 정보 조회 중...
#
# 📦 userId: PFS_0000007 - 작기 정보 조회 중...
#
# 📦 userId: PFS_0000008 - 작기 정보 조회 중...
#
# 📦 userId: PFS_0000009 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000002 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000004 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000005 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000006 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000007 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000008 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000009 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000010 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000011 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000012 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000013 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000014 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000015 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000016 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000017 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000018 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000019 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000020 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000034 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000039 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000040 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000042 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000043 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000047 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000099 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000116 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000125 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000185 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000192 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000227 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000243 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000265 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000279 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000304 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000365 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000594 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000806 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000842 - 작기 정보 조회 중...
#
# 📦 userId: PF_0000844 - 작기 정보 조회 중...
#
# 📦 userId: PF_0001001 - 작기 정보 조회 중...
#
# 📦 userId: PF_0001002 - 작기 정보 조회 중...
#
# 📦 userId: PF_0001009 - 작기 정보 조회 중...
#
# 📦 userId: PF_0001402 - 작기 정보 조회 중...
#
# 📦 userId: PF_0001405 - 작기 정보 조회 중...
#
# 📦 userId: PF_0001406 - 작기 정보 조회 중...
#
# 📦 userId: PF_0001412 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002525 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002526 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002527 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002528 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002529 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002531 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002532 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002547 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002548 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002551 - 작기 정보 조회 중...
#
# 📦 userId: PF_0002904 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006023 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006024 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006025 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006042 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006043 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006044 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006045 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006046 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006047 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006404 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006412 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006414 - 작기 정보 조회 중...
#
# 📦 userId: PF_0006415 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010009 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010013 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010014 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010015 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010016 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010017 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010018 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010019 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010020 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010022 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010054 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010056 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010057 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010059 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010066 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010068 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010071 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010075 - 작기 정보 조회 중...
#
# 📦 userId: PF_0010076 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020032 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020074 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020076 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020209 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020353 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020356 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020561 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020671 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020701 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020703 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020724 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020725 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020726 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020738 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020745 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020748 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020749 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020758 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020760 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020761 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020763 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020764 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020968 - 작기 정보 조회 중...
#
# 📦 userId: PF_0020974 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021193 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021196 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021197 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021199 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021200 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021229 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021230 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021231 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021232 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021233 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021234 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021235 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021236 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021237 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021238 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021239 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021240 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021241 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021242 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021244 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021245 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021246 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021247 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021248 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021249 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021250 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021251 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021252 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021253 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021254 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021255 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021256 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021257 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021258 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021259 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021260 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021261 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021262 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021263 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021264 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021265 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021266 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021267 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021268 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021269 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021270 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021271 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021272 - 작기 정보 조회 중...
#
# 📦 userId: PF_0021273 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022077 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022078 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022079 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022080 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022081 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022082 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022083 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022084 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022085 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022092 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022094 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022097 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022098 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022100 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022101 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022102 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022109 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022116 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022117 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022120 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022121 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022122 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022125 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022127 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022161 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022235 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022374 - 작기 정보 조회 중...
#
# 📦 userId: PF_0022376 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023488 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023490 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023494 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023495 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023505 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023513 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023521 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023609 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023610 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023611 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023612 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023613 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023615 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023616 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023617 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023618 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023619 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023623 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023624 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023625 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023626 - 작기 정보 조회 중...
#
# 📦 userId: PF_0023627 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024001 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024003 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024240 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024241 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024242 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024243 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024244 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024245 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024246 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024247 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024248 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024249 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024250 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024251 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024252 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024253 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024377 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024541 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024656 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024689 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024693 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024696 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024697 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024698 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024858 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024859 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024860 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024861 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024862 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024863 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024864 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024865 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024866 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024867 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024868 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024869 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024870 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024871 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024872 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024873 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024874 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024875 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024876 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024877 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024878 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024879 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024880 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024881 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024882 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024883 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024884 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024885 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024886 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024887 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024888 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024889 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024890 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024891 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024892 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024893 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024894 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024895 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024896 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024897 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024898 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024899 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024900 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024901 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024902 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024903 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024904 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024905 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024906 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024907 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024908 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024909 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024910 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024911 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024912 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024913 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024914 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024915 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024916 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024917 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024918 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024919 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024920 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024921 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024922 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024923 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024924 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024925 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024926 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024927 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024928 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024929 - 작기 정보 조회 중...
#
# 📦 userId: PF_0024930 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025101 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025108 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025286 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025290 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025291 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025292 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025293 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025294 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025295 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025296 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025297 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025298 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025299 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025300 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025301 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025302 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025303 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025304 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025305 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025306 - 작기 정보 조회 중...
#
# 📦 userId: PF_0025307 - 작기 정보 조회 중...
#
# 📦 userId: sk0015 - 작기 정보 조회 중...
#
# 📦 userId: sk0019 - 작기 정보 조회 중...
#
# 📦 userId: sk0023 - 작기 정보 조회 중...
#
# 📦 userId: sk0026 - 작기 정보 조회 중...
#
# 📦 userId: sk0047 - 작기 정보 조회 중...
#
# 📦 userId: sk0057 - 작기 정보 조회 중...
#
# 📦 userId: sk0058 - 작기 정보 조회 중...
#
# 📦 userId: sk0063 - 작기 정보 조회 중...
#
# 📦 userId: sk0065 - 작기 정보 조회 중...
#
# 📦 userId: sk0073 - 작기 정보 조회 중...
#
# 📦 userId: sk0078 - 작기 정보 조회 중...
#
# 📦 userId: sk0081 - 작기 정보 조회 중...
#
# 📦 userId: sk0085 - 작기 정보 조회 중...
#
# 📦 userId: sk0091 - 작기 정보 조회 중...
#
# 📦 userId: sk0102 - 작기 정보 조회 중...
#
# 📦 userId: sk0104 - 작기 정보 조회 중...
#
# 📦 userId: sk0118 - 작기 정보 조회 중...

# %%
#check data
user_id = "PFS_0000001"             # 예시: 실제 userId
cropping_serl_no = 79               # 작기 일련번호
start_date = "2015-09-02"          # 작기 시작일
end_date = "2016-12-31"            # 작기 종료일

# user_id = "PFS_0000008"             # 예시: 실제 userId # 데이터 없는 경우  "statusMessage": "NODATA_ERROR",
# cropping_serl_no = 77               # 작기 일련번호
# start_date = "2015-07-29"          # 작기 시작일
# end_date = "2016-12-31"            # 작기 종료일

# URL 구성
url = f"http://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getCultivateDataList/{service_key}/{user_id}/{cropping_serl_no}/{start_date}/{end_date}"

# 요청 및 출력
try:
    response = requests.get(url, timeout=10)
    response.raise_for_status()
    data = response.json()
    if data:
        print("✅ 생육 데이터 존재:")
        print(json.dumps(data, indent=2, ensure_ascii=False))
    else:
        print("🚫 생육 데이터 없음")
except Exception as e:
    print(f"❌ 요청 실패: {e}")
# Out:
# ✅ 생육 데이터 존재:
# [
#   {
#     "statusCode": "00",
#     "statusMessage": "NORMAL_CODE",
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-09-06",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 0.0,
#     "fruitsPosition": 0.0,
#     "fruitsNum": 0.0,
#     "harvestPosition": 0.0,
#     "ped": 5451.0,
#     "solarCorrection": 1716.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-09-13",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 455.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4092.0,
#     "solarCorrection": 3624.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-09-20",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 448.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3654.0,
#     "solarCorrection": 6744.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-09-27",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 16.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4674.0,
#     "solarCorrection": 5565.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-10-04",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 16.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 2283.0,
#     "solarCorrection": 2718.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-10-11",
#     "growLength": 240.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.9,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 1251.0,
#     "solarCorrection": 5604.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-10-18",
#     "growLength": 230.0,
#     "flowerTop": 250.0,
#     "stemDiameter": 15.5,
#     "leavesLength": 470.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 825.0,
#     "solarCorrection": 5409.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-10-25",
#     "growLength": 210.0,
#     "flowerTop": 260.0,
#     "stemDiameter": 14.3,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 24.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3978.0,
#     "solarCorrection": 1719.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-11-01",
#     "growLength": 230.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.8,
#     "leavesLength": 460.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4554.0,
#     "solarCorrection": 5694.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-11-08",
#     "growLength": 220.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 23.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2619.0,
#     "solarCorrection": 2223.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-11-15",
#     "growLength": 210.0,
#     "flowerTop": 230.0,
#     "stemDiameter": 12.6,
#     "leavesLength": 450.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4749.0,
#     "solarCorrection": 1524.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-11-22",
#     "growLength": 180.0,
#     "flowerTop": 220.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 7164.0,
#     "solarCorrection": 5304.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-11-29",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.4,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 768.0,
#     "solarCorrection": 7200.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-12-06",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 741.0,
#     "solarCorrection": 765.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-12-13",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.2,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2799.0,
#     "solarCorrection": 6375.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-12-20",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 480.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2751.0,
#     "solarCorrection": 6402.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2015-12-27",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 759.0,
#     "solarCorrection": 7173.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-01-03",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-01-10",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-01-17",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 390.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-01-24",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 439.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-01-31",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-02-07",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-02-14",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-02-21",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-02-28",
#     "growLength": 200.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-03-06",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-03-13",
#     "growLength": 200.0,
#     "flowerTop": 190.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-03-20",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "1",
#     "measDate": "2016-03-27",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-09-06",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 0.0,
#     "fruitsPosition": 0.0,
#     "fruitsNum": 0.0,
#     "harvestPosition": 0.0,
#     "ped": 5451.0,
#     "solarCorrection": 1716.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-09-13",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 455.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4092.0,
#     "solarCorrection": 3624.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-09-20",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 448.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3654.0,
#     "solarCorrection": 6744.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-09-27",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 16.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4674.0,
#     "solarCorrection": 5565.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-10-04",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 16.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 2283.0,
#     "solarCorrection": 2718.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-10-11",
#     "growLength": 240.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.9,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 1251.0,
#     "solarCorrection": 5604.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-10-18",
#     "growLength": 230.0,
#     "flowerTop": 250.0,
#     "stemDiameter": 15.5,
#     "leavesLength": 470.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 825.0,
#     "solarCorrection": 5409.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-10-25",
#     "growLength": 210.0,
#     "flowerTop": 260.0,
#     "stemDiameter": 14.3,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 24.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3978.0,
#     "solarCorrection": 1719.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-11-01",
#     "growLength": 230.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.8,
#     "leavesLength": 460.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4554.0,
#     "solarCorrection": 5694.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-11-08",
#     "growLength": 220.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 23.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2619.0,
#     "solarCorrection": 2223.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-11-15",
#     "growLength": 210.0,
#     "flowerTop": 230.0,
#     "stemDiameter": 12.6,
#     "leavesLength": 450.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4749.0,
#     "solarCorrection": 1524.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-11-22",
#     "growLength": 180.0,
#     "flowerTop": 220.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 7164.0,
#     "solarCorrection": 5304.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-11-29",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.4,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 768.0,
#     "solarCorrection": 7200.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-12-06",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 741.0,
#     "solarCorrection": 765.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-12-13",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.2,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2799.0,
#     "solarCorrection": 6375.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-12-20",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 480.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2751.0,
#     "solarCorrection": 6402.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2015-12-27",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 759.0,
#     "solarCorrection": 7173.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-01-03",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-01-10",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-01-17",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 390.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-01-24",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 439.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-01-31",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-02-07",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-02-14",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-02-21",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-02-28",
#     "growLength": 200.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-03-06",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-03-13",
#     "growLength": 200.0,
#     "flowerTop": 190.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-03-20",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "2",
#     "measDate": "2016-03-27",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-09-06",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 0.0,
#     "fruitsPosition": 0.0,
#     "fruitsNum": 0.0,
#     "harvestPosition": 0.0,
#     "ped": 5451.0,
#     "solarCorrection": 1716.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-09-13",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 455.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4092.0,
#     "solarCorrection": 3624.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-09-20",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 448.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3654.0,
#     "solarCorrection": 6744.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-09-27",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 16.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4674.0,
#     "solarCorrection": 5565.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-10-04",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 16.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 2283.0,
#     "solarCorrection": 2718.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-10-11",
#     "growLength": 240.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.9,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 1251.0,
#     "solarCorrection": 5604.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-10-18",
#     "growLength": 230.0,
#     "flowerTop": 250.0,
#     "stemDiameter": 15.5,
#     "leavesLength": 470.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 825.0,
#     "solarCorrection": 5409.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-10-25",
#     "growLength": 210.0,
#     "flowerTop": 260.0,
#     "stemDiameter": 14.3,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 24.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3978.0,
#     "solarCorrection": 1719.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-11-01",
#     "growLength": 230.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.8,
#     "leavesLength": 460.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4554.0,
#     "solarCorrection": 5694.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-11-08",
#     "growLength": 220.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 23.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2619.0,
#     "solarCorrection": 2223.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-11-15",
#     "growLength": 210.0,
#     "flowerTop": 230.0,
#     "stemDiameter": 12.6,
#     "leavesLength": 450.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4749.0,
#     "solarCorrection": 1524.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-11-22",
#     "growLength": 180.0,
#     "flowerTop": 220.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 7164.0,
#     "solarCorrection": 5304.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-11-29",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.4,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 768.0,
#     "solarCorrection": 7200.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-12-06",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 741.0,
#     "solarCorrection": 765.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-12-13",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.2,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2799.0,
#     "solarCorrection": 6375.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-12-20",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 480.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2751.0,
#     "solarCorrection": 6402.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2015-12-27",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 759.0,
#     "solarCorrection": 7173.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-01-03",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-01-10",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-01-17",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 390.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-01-24",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 439.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-01-31",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-02-07",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-02-14",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-02-21",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-02-28",
#     "growLength": 200.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-03-06",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-03-13",
#     "growLength": 200.0,
#     "flowerTop": 190.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-03-20",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "3",
#     "measDate": "2016-03-27",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-09-06",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 0.0,
#     "fruitsPosition": 0.0,
#     "fruitsNum": 0.0,
#     "harvestPosition": 0.0,
#     "ped": 5451.0,
#     "solarCorrection": 1716.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-09-13",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 455.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4092.0,
#     "solarCorrection": 3624.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-09-20",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 14.0,
#     "leavesLength": 448.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3654.0,
#     "solarCorrection": 6744.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-09-27",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 15.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 16.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 4674.0,
#     "solarCorrection": 5565.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-10-04",
#     "growLength": 210.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 16.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 2283.0,
#     "solarCorrection": 2718.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-10-11",
#     "growLength": 240.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.9,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 1251.0,
#     "solarCorrection": 5604.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-10-18",
#     "growLength": 230.0,
#     "flowerTop": 250.0,
#     "stemDiameter": 15.5,
#     "leavesLength": 470.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 825.0,
#     "solarCorrection": 5409.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-10-25",
#     "growLength": 210.0,
#     "flowerTop": 260.0,
#     "stemDiameter": 14.3,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 24.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 3978.0,
#     "solarCorrection": 1719.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-11-01",
#     "growLength": 230.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.8,
#     "leavesLength": 460.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4554.0,
#     "solarCorrection": 5694.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-11-08",
#     "growLength": 220.0,
#     "flowerTop": 240.0,
#     "stemDiameter": 13.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 23.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2619.0,
#     "solarCorrection": 2223.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-11-15",
#     "growLength": 210.0,
#     "flowerTop": 230.0,
#     "stemDiameter": 12.6,
#     "leavesLength": 450.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 4749.0,
#     "solarCorrection": 1524.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-11-22",
#     "growLength": 180.0,
#     "flowerTop": 220.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 7164.0,
#     "solarCorrection": 5304.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-11-29",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.4,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 768.0,
#     "solarCorrection": 7200.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-12-06",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 741.0,
#     "solarCorrection": 765.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-12-13",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.2,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2799.0,
#     "solarCorrection": 6375.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-12-20",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.5,
#     "leavesLength": 480.0,
#     "leavesWidth": 430.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 2751.0,
#     "solarCorrection": 6402.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2015-12-27",
#     "growLength": 170.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 759.0,
#     "solarCorrection": 7173.0,
#     "fruitsWeight": 180.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-01-03",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 17.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-01-10",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-01-17",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 390.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-01-24",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 10.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 439.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-01-31",
#     "growLength": 180.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 2.0,
#     "fruitsPosition": 2.0,
#     "fruitsNum": 2.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-02-07",
#     "growLength": 190.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 19.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-02-14",
#     "growLength": 180.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 470.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 18.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-02-21",
#     "growLength": 190.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 11.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 400.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-02-28",
#     "growLength": 200.0,
#     "flowerTop": 210.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-03-06",
#     "growLength": 200.0,
#     "flowerTop": 200.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-03-13",
#     "growLength": 200.0,
#     "flowerTop": 190.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 420.0,
#     "leavesNum": 22.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-03-20",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 450.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 21.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   },
#   {
#     "statusCode": null,
#     "statusMessage": null,
#     "userId": "PFS_0000001",
#     "itemCode": "080300",
#     "sampleNum": "4",
#     "measDate": "2016-03-27",
#     "growLength": 200.0,
#     "flowerTop": 180.0,
#     "stemDiameter": 12.0,
#     "leavesLength": 460.0,
#     "leavesWidth": 410.0,
#     "leavesNum": 20.0,
#     "flowerPosition": 3.0,
#     "fruitsPosition": 3.0,
#     "fruitsNum": 3.0,
#     "harvestPosition": 0.0,
#     "ped": 0.0,
#     "solarCorrection": 0.0,
#     "fruitsWeight": 0.0
#   }
# ]

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed

with open("tomato_cropping_data.json", "r", encoding="utf-8") as f:
    tomato_cropping_data = json.load(f)

# 요청 목록 생성
request_args = []
for entry in tomato_cropping_data:
    user_id = entry.get("userId")
    for crop in entry.get("croppingData", []):
        serl_no = crop.get("croppingSerlNo")
        start = crop.get("croppingDate")
        end = crop.get("croppingEndDate")
        if all([user_id, serl_no, start, end]):
            request_args.append((user_id, serl_no, start, end))

# 병렬 실행
valid_entries = []
total = len(request_args)
completed = 0

with ThreadPoolExecutor(max_workers=10) as executor:
    futures = [executor.submit(get_cultivate_data_safe, args) for args in request_args]
    for future in as_completed(futures):
        completed += 1
        result = future.result()
        if result:
            valid_entries.append(result)
            print(f"✅ {completed}/{total} | 생육 데이터 있음: userId={result['userId']} serlNo={result['croppingSerlNo']}")
        else:
            print(f"❌ {completed}/{total} | 생육 데이터 없음")

# JSON 저장
with open("./data/tomato_cultivate_data_valid.json", "w", encoding="utf-8") as f:
    json.dump(valid_entries, f, ensure_ascii=False, indent=2)

# 요약 출력
print(f"\n🎯 최종 요약")
print(f"✅ 생육 데이터 있는 항목: {len(valid_entries)}개")
print(f"🚫 생육 데이터 없는 항목: {total - len(valid_entries)}개")
# Out:
# ❌ 1/553 | 생육 데이터 없음
# ✅ 2/553 | 생육 데이터 있음: userId=PFS_0000008 serlNo=71
# ✅ 3/553 | 생육 데이터 있음: userId=PFS_0000008 serlNo=536
# ✅ 4/553 | 생육 데이터 있음: userId=PFS_0000002 serlNo=80
# ✅ 5/553 | 생육 데이터 있음: userId=PFS_0000001 serlNo=79
# ✅ 6/553 | 생육 데이터 있음: userId=PFS_0000001 serlNo=4940
# ✅ 7/553 | 생육 데이터 있음: userId=PFS_0000006 serlNo=69
# ✅ 8/553 | 생육 데이터 있음: userId=PFS_0000004 serlNo=82
# ✅ 9/553 | 생육 데이터 있음: userId=PFS_0000007 serlNo=70
# ✅ 10/553 | 생육 데이터 있음: userId=PFS_0000003 serlNo=81
# ❌ 11/553 | 생육 데이터 없음
# ❌ 12/553 | 생육 데이터 없음
# ❌ 13/553 | 생육 데이터 없음
# ✅ 14/553 | 생육 데이터 있음: userId=PFS_0000008 serlNo=4809
# ✅ 15/553 | 생육 데이터 있음: userId=PFS_0000008 serlNo=5377
# ❌ 16/553 | 생육 데이터 없음
# ✅ 17/553 | 생육 데이터 있음: userId=PF_0000002 serlNo=204
# ✅ 18/553 | 생육 데이터 있음: userId=PFS_0000009 serlNo=72
# ✅ 19/553 | 생육 데이터 있음: userId=PF_0000002 serlNo=43
# ✅ 20/553 | 생육 데이터 있음: userId=PF_0000004 serlNo=38
# ✅ 21/553 | 생육 데이터 있음: userId=PF_0000005 serlNo=87
# ✅ 22/553 | 생육 데이터 있음: userId=PF_0000004 serlNo=88
# ✅ 23/553 | 생육 데이터 있음: userId=PF_0000005 serlNo=33
# ✅ 24/553 | 생육 데이터 있음: userId=PF_0000007 serlNo=31
# ✅ 25/553 | 생육 데이터 있음: userId=PF_0000006 serlNo=39
# ✅ 26/553 | 생육 데이터 있음: userId=PF_0000009 serlNo=40
# ✅ 27/553 | 생육 데이터 있음: userId=PF_0000007 serlNo=32
# ✅ 28/553 | 생육 데이터 있음: userId=PF_0000008 serlNo=35
# ❌ 29/553 | 생육 데이터 없음
# ✅ 30/553 | 생육 데이터 있음: userId=PF_0000010 serlNo=48
# ❌ 31/553 | 생육 데이터 없음
# ✅ 32/553 | 생육 데이터 있음: userId=PF_0000010 serlNo=202
# ✅ 33/553 | 생육 데이터 있음: userId=PF_0000011 serlNo=205
# ✅ 34/553 | 생육 데이터 있음: userId=PF_0000011 serlNo=23
# ✅ 35/553 | 생육 데이터 있음: userId=PF_0000011 serlNo=24
# ✅ 36/553 | 생육 데이터 있음: userId=PF_0000012 serlNo=25
# ✅ 37/553 | 생육 데이터 있음: userId=PF_0000014 serlNo=27
# ✅ 38/553 | 생육 데이터 있음: userId=PF_0000014 serlNo=200
# ✅ 39/553 | 생육 데이터 있음: userId=PF_0000013 serlNo=22
# ✅ 40/553 | 생육 데이터 있음: userId=PF_0000015 serlNo=26
# ✅ 41/553 | 생육 데이터 있음: userId=PF_0000015 serlNo=196
# ✅ 42/553 | 생육 데이터 있음: userId=PF_0000016 serlNo=29
# ✅ 43/553 | 생육 데이터 있음: userId=PF_0000016 serlNo=30
# ✅ 44/553 | 생육 데이터 있음: userId=PF_0000017 serlNo=197
# ✅ 45/553 | 생육 데이터 있음: userId=PF_0000017 serlNo=28
# ❌ 46/553 | 생육 데이터 없음
# ✅ 47/553 | 생육 데이터 있음: userId=PF_0000018 serlNo=195
# ✅ 48/553 | 생육 데이터 있음: userId=PF_0000019 serlNo=186
# ✅ 49/553 | 생육 데이터 있음: userId=PF_0000018 serlNo=2007
# ✅ 50/553 | 생육 데이터 있음: userId=PF_0000020 serlNo=187
# ✅ 51/553 | 생육 데이터 있음: userId=PF_0000034 serlNo=201
# ✅ 52/553 | 생육 데이터 있음: userId=PF_0000034 serlNo=34
# ✅ 53/553 | 생육 데이터 있음: userId=PF_0000042 serlNo=297
# ✅ 54/553 | 생육 데이터 있음: userId=PF_0000039 serlNo=298
# ✅ 55/553 | 생육 데이터 있음: userId=PF_0000040 serlNo=300
# ❌ 56/553 | 생육 데이터 없음
# ✅ 57/553 | 생육 데이터 있음: userId=PF_0000043 serlNo=296
# ✅ 58/553 | 생육 데이터 있음: userId=PF_0000047 serlNo=399
# ✅ 59/553 | 생육 데이터 있음: userId=PF_0000099 serlNo=363
# ✅ 60/553 | 생육 데이터 있음: userId=PF_0000099 serlNo=314
# ❌ 61/553 | 생육 데이터 없음
# ✅ 62/553 | 생육 데이터 있음: userId=PF_0000099 serlNo=4076
# ❌ 63/553 | 생육 데이터 없음
# ✅ 64/553 | 생육 데이터 있음: userId=PF_0000116 serlNo=299
# ❌ 65/553 | 생육 데이터 없음
# ✅ 66/553 | 생육 데이터 있음: userId=PF_0000125 serlNo=317
# ✅ 67/553 | 생육 데이터 있음: userId=PF_0000185 serlNo=292
# ❌ 68/553 | 생육 데이터 없음
# ❌ 69/553 | 생육 데이터 없음
# ❌ 70/553 | 생육 데이터 없음
# ❌ 71/553 | 생육 데이터 없음
# ❌ 72/553 | 생육 데이터 없음
# ❌ 73/553 | 생육 데이터 없음
# ✅ 74/553 | 생육 데이터 있음: userId=PF_0000227 serlNo=320
# ❌ 75/553 | 생육 데이터 없음
# ✅ 76/553 | 생육 데이터 있음: userId=PF_0000227 serlNo=401
# ❌ 77/553 | 생육 데이터 없음
# ✅ 78/553 | 생육 데이터 있음: userId=PF_0000227 serlNo=510
# ❌ 79/553 | 생육 데이터 없음
# ❌ 80/553 | 생육 데이터 없음
# ✅ 81/553 | 생육 데이터 있음: userId=PF_0000227 serlNo=4732
# ✅ 82/553 | 생육 데이터 있음: userId=PF_0000265 serlNo=74
# ❌ 83/553 | 생육 데이터 없음
# ✅ 84/553 | 생육 데이터 있음: userId=PF_0000265 serlNo=2144
# ❌ 85/553 | 생육 데이터 없음
# ❌ 86/553 | 생육 데이터 없음
# ❌ 87/553 | 생육 데이터 없음
# ✅ 88/553 | 생육 데이터 있음: userId=PF_0000304 serlNo=294
# ✅ 89/553 | 생육 데이터 있음: userId=PF_0000304 serlNo=523
# ❌ 90/553 | 생육 데이터 없음
# ❌ 91/553 | 생육 데이터 없음
# ❌ 92/553 | 생육 데이터 없음
# ✅ 93/553 | 생육 데이터 있음: userId=PF_0000365 serlNo=349
# ✅ 94/553 | 생육 데이터 있음: userId=PF_0000806 serlNo=4054
# ✅ 95/553 | 생육 데이터 있음: userId=PF_0000594 serlNo=6
# ✅ 96/553 | 생육 데이터 있음: userId=PF_0000842 serlNo=402
# ✅ 97/553 | 생육 데이터 있음: userId=PF_0000806 serlNo=4820
# ✅ 98/553 | 생육 데이터 있음: userId=PF_0001001 serlNo=21
# ✅ 99/553 | 생육 데이터 있음: userId=PF_0001002 serlNo=20
# ✅ 100/553 | 생육 데이터 있음: userId=PF_0001009 serlNo=37
# ✅ 101/553 | 생육 데이터 있음: userId=PF_0001009 serlNo=199
# ✅ 102/553 | 생육 데이터 있음: userId=PF_0001402 serlNo=400
# ❌ 103/553 | 생육 데이터 없음
# ❌ 104/553 | 생육 데이터 없음
# ✅ 105/553 | 생육 데이터 있음: userId=PF_0001405 serlNo=295
# ✅ 106/553 | 생육 데이터 있음: userId=PF_0001405 serlNo=2400
# ✅ 107/553 | 생육 데이터 있음: userId=PF_0001405 serlNo=528
# ✅ 108/553 | 생육 데이터 있음: userId=PF_0001405 serlNo=3410
# ❌ 109/553 | 생육 데이터 없음
# ✅ 110/553 | 생육 데이터 있음: userId=PF_0001406 serlNo=350
# ✅ 111/553 | 생육 데이터 있음: userId=PF_0001405 serlNo=4760
# ✅ 112/553 | 생육 데이터 있음: userId=PF_0001412 serlNo=301
# ✅ 113/553 | 생육 데이터 있음: userId=PF_0002525 serlNo=2116
# ✅ 114/553 | 생육 데이터 있음: userId=PF_0002525 serlNo=488
# ❌ 115/553 | 생육 데이터 없음
# ❌ 116/553 | 생육 데이터 없음
# ❌ 117/553 | 생육 데이터 없음
# ✅ 118/553 | 생육 데이터 있음: userId=PF_0002526 serlNo=529
# ✅ 119/553 | 생육 데이터 있음: userId=PF_0002525 serlNo=2961
# ❌ 120/553 | 생육 데이터 없음
# ✅ 121/553 | 생육 데이터 있음: userId=PF_0002527 serlNo=519
# ✅ 122/553 | 생육 데이터 있음: userId=PF_0002527 serlNo=2117
# ✅ 123/553 | 생육 데이터 있음: userId=PF_0002527 serlNo=4719
# ❌ 124/553 | 생육 데이터 없음
# ✅ 125/553 | 생육 데이터 있음: userId=PF_0002528 serlNo=4801
# ✅ 126/553 | 생육 데이터 있음: userId=PF_0002527 serlNo=5038
# ❌ 127/553 | 생육 데이터 없음
# ❌ 128/553 | 생육 데이터 없음
# ✅ 129/553 | 생육 데이터 있음: userId=PF_0002528 serlNo=5079
# ❌ 130/553 | 생육 데이터 없음
# ✅ 131/553 | 생육 데이터 있음: userId=PF_0002528 serlNo=532
# ✅ 132/553 | 생육 데이터 있음: userId=PF_0002529 serlNo=514
# ❌ 133/553 | 생육 데이터 없음
# ✅ 134/553 | 생육 데이터 있음: userId=PF_0002531 serlNo=2128
# ✅ 135/553 | 생육 데이터 있음: userId=PF_0002529 serlNo=7575
# ✅ 136/553 | 생육 데이터 있음: userId=PF_0002531 serlNo=531
# ❌ 137/553 | 생육 데이터 없음
# ❌ 138/553 | 생육 데이터 없음
# ✅ 139/553 | 생육 데이터 있음: userId=PF_0002531 serlNo=3403
# ✅ 140/553 | 생육 데이터 있음: userId=PF_0002532 serlNo=503
# ✅ 141/553 | 생육 데이터 있음: userId=PF_0002531 serlNo=4796
# ❌ 142/553 | 생육 데이터 없음
# ❌ 143/553 | 생육 데이터 없음
# ❌ 144/553 | 생육 데이터 없음
# ✅ 145/553 | 생육 데이터 있음: userId=PF_0002532 serlNo=4800
# ✅ 146/553 | 생육 데이터 있음: userId=PF_0002547 serlNo=533
# ✅ 147/553 | 생육 데이터 있음: userId=PF_0002551 serlNo=511
# ❌ 148/553 | 생육 데이터 없음
# ❌ 149/553 | 생육 데이터 없음
# ❌ 150/553 | 생육 데이터 없음
# ✅ 151/553 | 생육 데이터 있음: userId=PF_0006023 serlNo=2308
# ❌ 152/553 | 생육 데이터 없음
# ✅ 153/553 | 생육 데이터 있음: userId=PF_0006024 serlNo=2319
# ❌ 154/553 | 생육 데이터 없음
# ❌ 155/553 | 생육 데이터 없음
# ❌ 156/553 | 생육 데이터 없음
# ❌ 157/553 | 생육 데이터 없음
# ❌ 158/553 | 생육 데이터 없음
# ✅ 159/553 | 생육 데이터 있음: userId=PF_0006025 serlNo=2309
# ✅ 160/553 | 생육 데이터 있음: userId=PF_0006042 serlNo=2303
# ❌ 161/553 | 생육 데이터 없음
# ❌ 162/553 | 생육 데이터 없음
# ❌ 163/553 | 생육 데이터 없음
# ❌ 164/553 | 생육 데이터 없음
# ❌ 165/553 | 생육 데이터 없음
# ✅ 166/553 | 생육 데이터 있음: userId=PF_0006043 serlNo=3349
# ❌ 167/553 | 생육 데이터 없음
# ❌ 168/553 | 생육 데이터 없음
# ✅ 169/553 | 생육 데이터 있음: userId=PF_0006043 serlNo=2322
# ❌ 170/553 | 생육 데이터 없음
# ❌ 171/553 | 생육 데이터 없음
# ❌ 172/553 | 생육 데이터 없음
# ❌ 173/553 | 생육 데이터 없음
# ❌ 174/553 | 생육 데이터 없음
# ❌ 175/553 | 생육 데이터 없음
# ❌ 176/553 | 생육 데이터 없음
# ❌ 177/553 | 생육 데이터 없음
# ❌ 178/553 | 생육 데이터 없음
# ❌ 179/553 | 생육 데이터 없음
# ❌ 180/553 | 생육 데이터 없음
# ❌ 181/553 | 생육 데이터 없음
# ❌ 182/553 | 생육 데이터 없음
# ❌ 183/553 | 생육 데이터 없음
# ❌ 184/553 | 생육 데이터 없음
# ✅ 185/553 | 생육 데이터 있음: userId=PF_0010014 serlNo=3236
# ✅ 186/553 | 생육 데이터 있음: userId=PF_0010014 serlNo=4577
# ✅ 187/553 | 생육 데이터 있음: userId=PF_0010014 serlNo=2105
# ✅ 188/553 | 생육 데이터 있음: userId=PF_0010014 serlNo=3140
# ✅ 189/553 | 생육 데이터 있음: userId=PF_0010014 serlNo=4951
# ❌ 190/553 | 생육 데이터 없음
# ❌ 191/553 | 생육 데이터 없음
# ✅ 192/553 | 생육 데이터 있음: userId=PF_0010016 serlNo=2107
# ❌ 193/553 | 생육 데이터 없음
# ❌ 194/553 | 생육 데이터 없음
# ❌ 195/553 | 생육 데이터 없음
# ❌ 196/553 | 생육 데이터 없음
# ❌ 197/553 | 생육 데이터 없음
# ✅ 198/553 | 생육 데이터 있음: userId=PF_0010019 serlNo=2442
# ❌ 199/553 | 생육 데이터 없음
# ✅ 200/553 | 생육 데이터 있음: userId=PF_0010022 serlNo=2112
# ✅ 201/553 | 생육 데이터 있음: userId=PF_0010022 serlNo=4730
# ❌ 202/553 | 생육 데이터 없음
# ✅ 203/553 | 생육 데이터 있음: userId=PF_0010054 serlNo=2246
# ❌ 204/553 | 생육 데이터 없음
# ✅ 205/553 | 생육 데이터 있음: userId=PF_0010056 serlNo=2248
# ✅ 206/553 | 생육 데이터 있음: userId=PF_0010056 serlNo=3061
# ❌ 207/553 | 생육 데이터 없음
# ✅ 208/553 | 생육 데이터 있음: userId=PF_0010056 serlNo=3181
# ❌ 209/553 | 생육 데이터 없음
# ✅ 210/553 | 생육 데이터 있음: userId=PF_0010056 serlNo=4420
# ✅ 211/553 | 생육 데이터 있음: userId=PF_0010056 serlNo=4755
# ✅ 212/553 | 생육 데이터 있음: userId=PF_0010056 serlNo=5031
# ❌ 213/553 | 생육 데이터 없음
# ✅ 214/553 | 생육 데이터 있음: userId=PF_0010057 serlNo=3383
# ✅ 215/553 | 생육 데이터 있음: userId=PF_0010056 serlNo=7572
# ✅ 216/553 | 생육 데이터 있음: userId=PF_0010057 serlNo=2249
# ✅ 217/553 | 생육 데이터 있음: userId=PF_0010057 serlNo=4737
# ✅ 218/553 | 생육 데이터 있음: userId=PF_0010057 serlNo=7574
# ✅ 219/553 | 생육 데이터 있음: userId=PF_0010059 serlNo=2252
# ❌ 220/553 | 생육 데이터 없음
# ✅ 221/553 | 생육 데이터 있음: userId=PF_0010066 serlNo=2260
# ❌ 222/553 | 생육 데이터 없음
# ❌ 223/553 | 생육 데이터 없음
# ❌ 224/553 | 생육 데이터 없음
# ✅ 225/553 | 생육 데이터 있음: userId=PF_0010071 serlNo=2264
# ✅ 226/553 | 생육 데이터 있음: userId=PF_0010071 serlNo=3060
# ❌ 227/553 | 생육 데이터 없음
# ✅ 228/553 | 생육 데이터 있음: userId=PF_0010071 serlNo=3180
# ❌ 229/553 | 생육 데이터 없음
# ✅ 230/553 | 생육 데이터 있음: userId=PF_0010071 serlNo=4419
# ❌ 231/553 | 생육 데이터 없음
# ✅ 232/553 | 생육 데이터 있음: userId=PF_0010075 serlNo=2268
# ✅ 233/553 | 생육 데이터 있음: userId=PF_0010075 serlNo=3200
# ✅ 234/553 | 생육 데이터 있음: userId=PF_0010076 serlNo=2269
# ❌ 235/553 | 생육 데이터 없음
# ✅ 236/553 | 생육 데이터 있음: userId=PF_0010075 serlNo=4751
# ✅ 237/553 | 생육 데이터 있음: userId=PF_0010076 serlNo=3380
# ✅ 238/553 | 생육 데이터 있음: userId=PF_0010076 serlNo=2740
# ✅ 239/553 | 생육 데이터 있음: userId=PF_0010076 serlNo=4430
# ✅ 240/553 | 생육 데이터 있음: userId=PF_0010076 serlNo=4757
# ❌ 241/553 | 생육 데이터 없음
# ❌ 242/553 | 생육 데이터 없음
# ❌ 243/553 | 생육 데이터 없음
# ❌ 244/553 | 생육 데이터 없음
# ✅ 245/553 | 생육 데이터 있음: userId=PF_0020074 serlNo=4072
# ✅ 246/553 | 생육 데이터 있음: userId=PF_0020074 serlNo=4839
# ✅ 247/553 | 생육 데이터 있음: userId=PF_0020209 serlNo=7534
# ❌ 248/553 | 생육 데이터 없음
# ❌ 249/553 | 생육 데이터 없음
# ✅ 250/553 | 생육 데이터 있음: userId=PF_0020356 serlNo=3300
# ✅ 251/553 | 생육 데이터 있음: userId=PF_0020356 serlNo=4685
# ✅ 252/553 | 생육 데이터 있음: userId=PF_0020356 serlNo=5417
# ❌ 253/553 | 생육 데이터 없음
# ❌ 254/553 | 생육 데이터 없음
# ✅ 255/553 | 생육 데이터 있음: userId=PF_0020356 serlNo=7570
# ❌ 256/553 | 생육 데이터 없음
# ❌ 257/553 | 생육 데이터 없음
# ✅ 258/553 | 생육 데이터 있음: userId=PF_0020671 serlNo=4526
# ✅ 259/553 | 생육 데이터 있음: userId=PF_0020701 serlNo=4035
# ❌ 260/553 | 생육 데이터 없음
# ✅ 261/553 | 생육 데이터 있음: userId=PF_0020703 serlNo=4037
# ✅ 262/553 | 생육 데이터 있음: userId=PF_0020724 serlNo=4100
# ❌ 263/553 | 생육 데이터 없음
# ✅ 264/553 | 생육 데이터 있음: userId=PF_0020726 serlNo=4097
# ✅ 265/553 | 생육 데이터 있음: userId=PF_0020725 serlNo=4101
# ✅ 266/553 | 생육 데이터 있음: userId=PF_0020738 serlNo=4077
# ✅ 267/553 | 생육 데이터 있음: userId=PF_0020738 serlNo=4549
# ✅ 268/553 | 생육 데이터 있음: userId=PF_0020738 serlNo=5041
# ❌ 269/553 | 생육 데이터 없음
# ❌ 270/553 | 생육 데이터 없음
# ✅ 271/553 | 생육 데이터 있음: userId=PF_0020745 serlNo=4557
# ❌ 272/553 | 생육 데이터 없음
# ✅ 273/553 | 생육 데이터 있음: userId=PF_0020745 serlNo=4862
# ❌ 274/553 | 생육 데이터 없음
# ✅ 275/553 | 생육 데이터 있음: userId=PF_0020748 serlNo=4514
# ✅ 276/553 | 생육 데이터 있음: userId=PF_0020748 serlNo=4860
# ❌ 277/553 | 생육 데이터 없음
# ❌ 278/553 | 생육 데이터 없음
# ✅ 279/553 | 생육 데이터 있음: userId=PF_0020745 serlNo=4434
# ✅ 280/553 | 생육 데이터 있음: userId=PF_0020738 serlNo=5480
# ❌ 281/553 | 생육 데이터 없음
# ✅ 282/553 | 생육 데이터 있음: userId=PF_0020749 serlNo=4436
# ✅ 283/553 | 생육 데이터 있음: userId=PF_0020758 serlNo=4934
# ✅ 284/553 | 생육 데이터 있음: userId=PF_0020758 serlNo=4423
# ❌ 285/553 | 생육 데이터 없음
# ✅ 286/553 | 생육 데이터 있음: userId=PF_0020760 serlNo=4427
# ✅ 287/553 | 생육 데이터 있음: userId=PF_0020760 serlNo=4827
# ❌ 288/553 | 생육 데이터 없음
# ✅ 289/553 | 생육 데이터 있음: userId=PF_0020761 serlNo=4425
# ✅ 290/553 | 생육 데이터 있음: userId=PF_0020761 serlNo=4817
# ❌ 291/553 | 생육 데이터 없음
# ✅ 292/553 | 생육 데이터 있음: userId=PF_0020763 serlNo=4431
# ❌ 293/553 | 생육 데이터 없음
# ✅ 294/553 | 생육 데이터 있음: userId=PF_0020763 serlNo=4927
# ❌ 295/553 | 생육 데이터 없음
# ❌ 296/553 | 생육 데이터 없음
# ❌ 297/553 | 생육 데이터 없음
# ✅ 298/553 | 생육 데이터 있음: userId=PF_0020968 serlNo=4444
# ❌ 299/553 | 생육 데이터 없음
# ✅ 300/553 | 생육 데이터 있음: userId=PF_0020968 serlNo=4980
# ✅ 301/553 | 생육 데이터 있음: userId=PF_0020974 serlNo=4504
# ✅ 302/553 | 생육 데이터 있음: userId=PF_0020974 serlNo=4828
# ✅ 303/553 | 생육 데이터 있음: userId=PF_0020974 serlNo=5197
# ❌ 304/553 | 생육 데이터 없음
# ❌ 305/553 | 생육 데이터 없음
# ❌ 306/553 | 생육 데이터 없음
# ✅ 307/553 | 생육 데이터 있음: userId=PF_0021193 serlNo=4451
# ✅ 308/553 | 생육 데이터 있음: userId=PF_0021196 serlNo=4453
# ✅ 309/553 | 생육 데이터 있음: userId=PF_0021197 serlNo=4454
# ✅ 310/553 | 생육 데이터 있음: userId=PF_0021199 serlNo=4455
# ✅ 311/553 | 생육 데이터 있음: userId=PF_0021229 serlNo=4494
# ✅ 312/553 | 생육 데이터 있음: userId=PF_0021200 serlNo=4456
# ✅ 313/553 | 생육 데이터 있음: userId=PF_0021230 serlNo=4493
# ✅ 314/553 | 생육 데이터 있음: userId=PF_0021231 serlNo=4457
# ✅ 315/553 | 생육 데이터 있음: userId=PF_0021232 serlNo=4492
# ✅ 316/553 | 생육 데이터 있음: userId=PF_0021233 serlNo=4458
# ✅ 317/553 | 생육 데이터 있음: userId=PF_0021234 serlNo=4491
# ✅ 318/553 | 생육 데이터 있음: userId=PF_0021235 serlNo=4495
# ✅ 319/553 | 생육 데이터 있음: userId=PF_0021236 serlNo=4490
# ✅ 320/553 | 생육 데이터 있음: userId=PF_0021237 serlNo=4489
# ✅ 321/553 | 생육 데이터 있음: userId=PF_0021240 serlNo=4486
# ✅ 322/553 | 생육 데이터 있음: userId=PF_0021239 serlNo=4487
# ✅ 323/553 | 생육 데이터 있음: userId=PF_0021238 serlNo=4488
# ✅ 324/553 | 생육 데이터 있음: userId=PF_0021242 serlNo=4484
# ✅ 325/553 | 생육 데이터 있음: userId=PF_0021241 serlNo=4485
# ✅ 326/553 | 생육 데이터 있음: userId=PF_0021244 serlNo=4483
# ✅ 327/553 | 생육 데이터 있음: userId=PF_0021245 serlNo=4482
# ✅ 328/553 | 생육 데이터 있음: userId=PF_0021246 serlNo=4481
# ✅ 329/553 | 생육 데이터 있음: userId=PF_0021247 serlNo=4480
# ✅ 330/553 | 생육 데이터 있음: userId=PF_0021248 serlNo=4478
# ❌ 331/553 | 생육 데이터 없음
# ✅ 332/553 | 생육 데이터 있음: userId=PF_0021249 serlNo=4496
# ✅ 333/553 | 생육 데이터 있음: userId=PF_0021250 serlNo=4502
# ❌ 334/553 | 생육 데이터 없음
# ✅ 335/553 | 생육 데이터 있음: userId=PF_0021251 serlNo=4497
# ✅ 336/553 | 생육 데이터 있음: userId=PF_0021252 serlNo=4459
# ✅ 337/553 | 생육 데이터 있음: userId=PF_0021254 serlNo=4460
# ✅ 338/553 | 생육 데이터 있음: userId=PF_0021253 serlNo=4498
# ✅ 339/553 | 생육 데이터 있음: userId=PF_0021255 serlNo=4477
# ✅ 340/553 | 생육 데이터 있음: userId=PF_0021256 serlNo=4499
# ❌ 341/553 | 생육 데이터 없음
# ✅ 342/553 | 생육 데이터 있음: userId=PF_0021258 serlNo=4461
# ✅ 343/553 | 생육 데이터 있음: userId=PF_0021259 serlNo=4462
# ✅ 344/553 | 생육 데이터 있음: userId=PF_0021260 serlNo=4475
# ✅ 345/553 | 생육 데이터 있음: userId=PF_0021261 serlNo=4463
# ✅ 346/553 | 생육 데이터 있음: userId=PF_0021262 serlNo=4474
# ✅ 347/553 | 생육 데이터 있음: userId=PF_0021264 serlNo=4500
# ✅ 348/553 | 생육 데이터 있음: userId=PF_0021263 serlNo=4464
# ✅ 349/553 | 생육 데이터 있음: userId=PF_0021265 serlNo=4465
# ✅ 350/553 | 생육 데이터 있음: userId=PF_0021266 serlNo=4466
# ✅ 351/553 | 생육 데이터 있음: userId=PF_0021268 serlNo=4467
# ✅ 352/553 | 생육 데이터 있음: userId=PF_0021267 serlNo=4473
# ✅ 353/553 | 생육 데이터 있음: userId=PF_0021270 serlNo=4468
# ✅ 354/553 | 생육 데이터 있음: userId=PF_0021269 serlNo=4472
# ✅ 355/553 | 생육 데이터 있음: userId=PF_0021272 serlNo=4471
# ✅ 356/553 | 생육 데이터 있음: userId=PF_0021271 serlNo=4469
# ✅ 357/553 | 생육 데이터 있음: userId=PF_0021273 serlNo=4470
# ✅ 358/553 | 생육 데이터 있음: userId=PF_0022077 serlNo=4941
# ❌ 359/553 | 생육 데이터 없음
# ✅ 360/553 | 생육 데이터 있음: userId=PF_0022078 serlNo=4918
# ❌ 361/553 | 생육 데이터 없음
# ✅ 362/553 | 생육 데이터 있음: userId=PF_0022079 serlNo=4921
# ❌ 363/553 | 생육 데이터 없음
# ❌ 364/553 | 생육 데이터 없음
# ✅ 365/553 | 생육 데이터 있음: userId=PF_0022080 serlNo=4925
# ✅ 366/553 | 생육 데이터 있음: userId=PF_0022081 serlNo=4920
# ✅ 367/553 | 생육 데이터 있음: userId=PF_0022082 serlNo=4937
# ✅ 368/553 | 생육 데이터 있음: userId=PF_0022083 serlNo=4902
# ❌ 369/553 | 생육 데이터 없음
# ✅ 370/553 | 생육 데이터 있음: userId=PF_0022083 serlNo=7568
# ❌ 371/553 | 생육 데이터 없음
# ✅ 372/553 | 생육 데이터 있음: userId=PF_0022084 serlNo=4952
# ✅ 373/553 | 생육 데이터 있음: userId=PF_0022085 serlNo=4948
# ✅ 374/553 | 생육 데이터 있음: userId=PF_0022097 serlNo=4915
# ✅ 375/553 | 생육 데이터 있음: userId=PF_0022092 serlNo=4923
# ✅ 376/553 | 생육 데이터 있음: userId=PF_0022094 serlNo=4916
# ❌ 377/553 | 생육 데이터 없음
# ✅ 378/553 | 생육 데이터 있음: userId=PF_0022097 serlNo=7567
# ❌ 379/553 | 생육 데이터 없음
# ✅ 380/553 | 생육 데이터 있음: userId=PF_0022098 serlNo=4910
# ❌ 381/553 | 생육 데이터 없음
# ❌ 382/553 | 생육 데이터 없음
# ✅ 383/553 | 생육 데이터 있음: userId=PF_0022102 serlNo=4905
# ✅ 384/553 | 생육 데이터 있음: userId=PF_0022100 serlNo=4922
# ✅ 385/553 | 생육 데이터 있음: userId=PF_0022102 serlNo=4919
# ✅ 386/553 | 생육 데이터 있음: userId=PF_0022102 serlNo=5035
# ❌ 387/553 | 생육 데이터 없음
# ✅ 388/553 | 생육 데이터 있음: userId=PF_0022109 serlNo=4911
# ❌ 389/553 | 생육 데이터 없음
# ✅ 390/553 | 생육 데이터 있음: userId=PF_0022116 serlNo=4909
# ✅ 391/553 | 생육 데이터 있음: userId=PF_0022116 serlNo=5037
# ❌ 392/553 | 생육 데이터 없음
# ✅ 393/553 | 생육 데이터 있음: userId=PF_0022117 serlNo=4955
# ✅ 394/553 | 생육 데이터 있음: userId=PF_0022117 serlNo=5237
# ❌ 395/553 | 생육 데이터 없음
# ✅ 396/553 | 생육 데이터 있음: userId=PF_0022120 serlNo=5463
# ✅ 397/553 | 생육 데이터 있음: userId=PF_0022121 serlNo=4965
# ❌ 398/553 | 생육 데이터 없음
# ✅ 399/553 | 생육 데이터 있음: userId=PF_0022122 serlNo=5462
# ❌ 400/553 | 생육 데이터 없음
# ✅ 401/553 | 생육 데이터 있음: userId=PF_0022127 serlNo=4978
# ✅ 402/553 | 생육 데이터 있음: userId=PF_0022125 serlNo=5057
# ✅ 403/553 | 생육 데이터 있음: userId=PF_0022161 serlNo=4967
# ❌ 404/553 | 생육 데이터 없음
# ✅ 405/553 | 생육 데이터 있음: userId=PF_0022376 serlNo=5033
# ❌ 406/553 | 생육 데이터 없음
# ✅ 407/553 | 생육 데이터 있음: userId=PF_0022374 serlNo=5032
# ❌ 408/553 | 생육 데이터 없음
# ❌ 409/553 | 생육 데이터 없음
# ❌ 410/553 | 생육 데이터 없음
# ❌ 411/553 | 생육 데이터 없음
# ❌ 412/553 | 생육 데이터 없음
# ❌ 413/553 | 생육 데이터 없음
# ❌ 414/553 | 생육 데이터 없음
# ❌ 415/553 | 생육 데이터 없음
# ❌ 416/553 | 생육 데이터 없음
# ❌ 417/553 | 생육 데이터 없음
# ❌ 418/553 | 생육 데이터 없음
# ❌ 419/553 | 생육 데이터 없음
# ❌ 420/553 | 생육 데이터 없음
# ❌ 421/553 | 생육 데이터 없음
# ❌ 422/553 | 생육 데이터 없음
# ❌ 423/553 | 생육 데이터 없음
# ❌ 424/553 | 생육 데이터 없음
# ❌ 425/553 | 생육 데이터 없음
# ❌ 426/553 | 생육 데이터 없음
# ❌ 427/553 | 생육 데이터 없음
# ❌ 428/553 | 생육 데이터 없음
# ❌ 429/553 | 생육 데이터 없음
# ❌ 430/553 | 생육 데이터 없음
# ❌ 431/553 | 생육 데이터 없음
# ❌ 432/553 | 생육 데이터 없음
# ✅ 433/553 | 생육 데이터 있음: userId=PF_0024656 serlNo=7536
# ❌ 434/553 | 생육 데이터 없음
# ✅ 435/553 | 생육 데이터 있음: userId=PF_0024689 serlNo=7557
# ✅ 436/553 | 생육 데이터 있음: userId=PF_0024693 serlNo=7553
# ✅ 437/553 | 생육 데이터 있음: userId=PF_0024696 serlNo=7550
# ✅ 438/553 | 생육 데이터 있음: userId=PF_0024697 serlNo=7549
# ✅ 439/553 | 생육 데이터 있음: userId=PF_0024698 serlNo=7548
# ❌ 440/553 | 생육 데이터 없음
# ❌ 441/553 | 생육 데이터 없음
# ❌ 442/553 | 생육 데이터 없음
# ❌ 443/553 | 생육 데이터 없음
# ❌ 444/553 | 생육 데이터 없음
# ❌ 445/553 | 생육 데이터 없음
# ❌ 446/553 | 생육 데이터 없음
# ❌ 447/553 | 생육 데이터 없음
# ❌ 448/553 | 생육 데이터 없음
# ❌ 449/553 | 생육 데이터 없음
# ❌ 450/553 | 생육 데이터 없음
# ❌ 451/553 | 생육 데이터 없음
# ❌ 452/553 | 생육 데이터 없음
# ❌ 453/553 | 생육 데이터 없음
# ❌ 454/553 | 생육 데이터 없음
# ❌ 455/553 | 생육 데이터 없음
# ❌ 456/553 | 생육 데이터 없음
# ❌ 457/553 | 생육 데이터 없음
# ❌ 458/553 | 생육 데이터 없음
# ❌ 459/553 | 생육 데이터 없음
# ❌ 460/553 | 생육 데이터 없음
# ❌ 461/553 | 생육 데이터 없음
# ❌ 462/553 | 생육 데이터 없음
# ❌ 463/553 | 생육 데이터 없음
# ❌ 464/553 | 생육 데이터 없음
# ❌ 465/553 | 생육 데이터 없음
# ❌ 466/553 | 생육 데이터 없음
# ❌ 467/553 | 생육 데이터 없음
# ❌ 468/553 | 생육 데이터 없음
# ❌ 469/553 | 생육 데이터 없음
# ❌ 470/553 | 생육 데이터 없음
# ❌ 471/553 | 생육 데이터 없음
# ❌ 472/553 | 생육 데이터 없음
# ❌ 473/553 | 생육 데이터 없음
# ❌ 474/553 | 생육 데이터 없음
# ❌ 475/553 | 생육 데이터 없음
# ❌ 476/553 | 생육 데이터 없음
# ❌ 477/553 | 생육 데이터 없음
# ❌ 478/553 | 생육 데이터 없음
# ❌ 479/553 | 생육 데이터 없음
# ❌ 480/553 | 생육 데이터 없음
# ❌ 481/553 | 생육 데이터 없음
# ❌ 482/553 | 생육 데이터 없음
# ❌ 483/553 | 생육 데이터 없음
# ❌ 484/553 | 생육 데이터 없음
# ❌ 485/553 | 생육 데이터 없음
# ❌ 486/553 | 생육 데이터 없음
# ❌ 487/553 | 생육 데이터 없음
# ❌ 488/553 | 생육 데이터 없음
# ❌ 489/553 | 생육 데이터 없음
# ❌ 490/553 | 생육 데이터 없음
# ❌ 491/553 | 생육 데이터 없음
# ❌ 492/553 | 생육 데이터 없음
# ❌ 493/553 | 생육 데이터 없음
# ❌ 494/553 | 생육 데이터 없음
# ❌ 495/553 | 생육 데이터 없음
# ❌ 496/553 | 생육 데이터 없음
# ❌ 497/553 | 생육 데이터 없음
# ❌ 498/553 | 생육 데이터 없음
# ❌ 499/553 | 생육 데이터 없음
# ❌ 500/553 | 생육 데이터 없음
# ❌ 501/553 | 생육 데이터 없음
# ❌ 502/553 | 생육 데이터 없음
# ❌ 503/553 | 생육 데이터 없음
# ❌ 504/553 | 생육 데이터 없음
# ❌ 505/553 | 생육 데이터 없음
# ❌ 506/553 | 생육 데이터 없음
# ❌ 507/553 | 생육 데이터 없음
# ❌ 508/553 | 생육 데이터 없음
# ❌ 509/553 | 생육 데이터 없음
# ❌ 510/553 | 생육 데이터 없음
# ❌ 511/553 | 생육 데이터 없음
# ❌ 512/553 | 생육 데이터 없음
# ❌ 513/553 | 생육 데이터 없음
# ❌ 514/553 | 생육 데이터 없음
# ✅ 515/553 | 생육 데이터 있음: userId=PF_0025101 serlNo=7525
# ✅ 516/553 | 생육 데이터 있음: userId=PF_0025108 serlNo=7519
# ❌ 517/553 | 생육 데이터 없음
# ❌ 518/553 | 생육 데이터 없음
# ❌ 519/553 | 생육 데이터 없음
# ❌ 520/553 | 생육 데이터 없음
# ❌ 521/553 | 생육 데이터 없음
# ❌ 522/553 | 생육 데이터 없음
# ❌ 523/553 | 생육 데이터 없음
# ❌ 524/553 | 생육 데이터 없음
# ❌ 525/553 | 생육 데이터 없음
# ❌ 526/553 | 생육 데이터 없음
# ❌ 527/553 | 생육 데이터 없음
# ❌ 528/553 | 생육 데이터 없음
# ❌ 529/553 | 생육 데이터 없음
# ❌ 530/553 | 생육 데이터 없음
# ❌ 531/553 | 생육 데이터 없음
# ❌ 532/553 | 생육 데이터 없음
# ❌ 533/553 | 생육 데이터 없음
# ✅ 534/553 | 생육 데이터 있음: userId=sk0015 serlNo=73
# ❌ 535/553 | 생육 데이터 없음
# ✅ 536/553 | 생육 데이터 있음: userId=sk0019 serlNo=52
# ✅ 537/553 | 생육 데이터 있음: userId=sk0023 serlNo=13
# ✅ 538/553 | 생육 데이터 있음: userId=sk0026 serlNo=50
# ✅ 539/553 | 생육 데이터 있음: userId=sk0047 serlNo=42
# ✅ 540/553 | 생육 데이터 있음: userId=sk0057 serlNo=12
# ✅ 541/553 | 생육 데이터 있음: userId=sk0058 serlNo=14
# ✅ 542/553 | 생육 데이터 있음: userId=sk0063 serlNo=11
# ✅ 543/553 | 생육 데이터 있음: userId=sk0065 serlNo=51
# ✅ 544/553 | 생육 데이터 있음: userId=sk0073 serlNo=9
# ✅ 545/553 | 생육 데이터 있음: userId=sk0078 serlNo=85
# ✅ 546/553 | 생육 데이터 있음: userId=sk0081 serlNo=41
# ✅ 547/553 | 생육 데이터 있음: userId=sk0085 serlNo=10
# ✅ 548/553 | 생육 데이터 있음: userId=sk0091 serlNo=45
# ✅ 549/553 | 생육 데이터 있음: userId=sk0102 serlNo=203
# ✅ 550/553 | 생육 데이터 있음: userId=sk0102 serlNo=44
# ✅ 551/553 | 생육 데이터 있음: userId=sk0104 serlNo=325
# ✅ 552/553 | 생육 데이터 있음: userId=sk0104 serlNo=326
# ✅ 553/553 | 생육 데이터 있음: userId=sk0118 serlNo=47
#
# 🎯 최종 요약
# ✅ 생육 데이터 있는 항목: 285개
# 🚫 생육 데이터 없는 항목: 268개

# %%
# 생육 + 환경데이터 있는 세트 불러오기
# EI = 내부환경데이터
EI_CODES = [
    "TI", "HI", "HI01", "HI02", "ID", "IR", "IS", "LI", "LW", "CI", "DT", "WS"
]

def get_env_data(service_key, facility_id, meas_date, item_code, fatr_code,
                 fld_code="FG", sect_code="EI"):
    url = f"http://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getEnvDataList/" \
          f"{service_key}/{facility_id}/{meas_date}/{fld_code}/{sect_code}/{fatr_code}/{item_code}"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        return data if data else None
    except Exception as e:
        print(f"❌ 환경 정보 실패: {facility_id}, {meas_date}, {fatr_code} → {e}")
        return None
    
# 1. load 생육 데이터와 농가정보 매핑
with open("tomato_cultivate_data_valid.json", "r", encoding="utf-8") as f:
    grow_data = json.load(f)

with open("identity_data.json", "r", encoding="utf-8") as f:
    identity_data = json.load(f)

# 2. userId → facilityId 매핑
user_facility = {d["userId"]: d["facilityId"] for d in identity_data if d.get("userId") and d.get("facilityId")}

# 3. 반복 수집
env_entries = []
for entry in grow_data:
    user_id = entry["userId"]
    facility_id = user_facility.get(user_id)
    if not facility_id:
        continue

    for grow_point in entry["cultivateData"]:
        meas_date = grow_point.get("measDate")  # yyyy-mm-dd
        item_code = grow_point.get("itemCode", "080300")
        if meas_date:
            for fatr_code in EI_CODES:
                env = get_env_data(service_key, facility_id, meas_date, item_code, fatr_code)
                if env:
                    env_entries.append({
                        "userId": user_id,
                        "facilityId": facility_id,
                        "measDate": meas_date,
                        "fatrCode": fatr_code,
                        "envData": env
                    })

# 4. 저장
with open("./data/tomato_env_data.json", "w", encoding="utf-8") as f:
    json.dump(env_entries, f, ensure_ascii=False, indent=2)
# Out:
# ❌ 환경 정보 실패: PFS_0000002_01, 2016-02-14, IR → 502 Server Error: Bad Gateway for url: https://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getEnvDataList/94cec237e4b943bfbb0e499d779025df/PFS_0000002_01/2016-02-14/FG/EI/IR/080300
# ❌ 환경 정보 실패: PFS_0000008_01, 2021-12-15, HI → 502 Server Error: Bad Gateway for url: https://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getEnvDataList/94cec237e4b943bfbb0e499d779025df/PFS_0000008_01/2021-12-15/FG/EI/HI/090100
# ❌ 환경 정보 실패: PF_0002528_01, 2022-06-29, IS → HTTPSConnectionPool(host='www.smartfarmkorea.net', port=443): Read timed out. (read timeout=10)
# ❌ 환경 정보 실패: PF_0002528_01, 2018-10-29, DT → HTTPSConnectionPool(host='www.smartfarmkorea.net', port=443): Read timed out. (read timeout=10)
# ❌ 환경 정보 실패: PF_0002528_01, 2019-04-22, TI → 502 Server Error: Bad Gateway for url: https://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getEnvDataList/94cec237e4b943bfbb0e499d779025df/PF_0002528_01/2019-04-22/FG/EI/TI/080300
# ❌ 환경 정보 실패: PF_0002551_01, 2018-11-20, ID → 502 Server Error: Bad Gateway for url: https://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getEnvDataList/94cec237e4b943bfbb0e499d779025df/PF_0002551_01/2018-11-20/FG/EI/ID/080300
# ❌ 환경 정보 실패: PF_0010014_01, 2019-10-26, HI02 → 502 Server Error: Bad Gateway for url: https://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getEnvDataList/94cec237e4b943bfbb0e499d779025df/PF_0010014_01/2019-10-26/FG/EI/HI02/080300
# ❌ 환경 정보 실패: PF_0010014_01, 2019-11-03, ID → 502 Server Error: Bad Gateway for url: https://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getEnvDataList/94cec237e4b943bfbb0e499d779025df/PF_0010014_01/2019-11-03/FG/EI/ID/080300
# ❌ 환경 정보 실패: PF_0010014_01, 2020-01-19, LI → 502 Server Error: Bad Gateway for url: https://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getEnvDataList/94cec237e4b943bfbb0e499d779025df/PF_0010014_01/2020-01-19/FG/EI/LI/080300
# ❌ 환경 정보 실패: PF_0021269_01, 2017-01-01, ID → 502 Server Error: Bad Gateway for url: https://www.smartfarmkorea.net/Agree_WS/webservices/ProvideRestService/getEnvDataList/94cec237e4b943bfbb0e499d779025df/PF_0021269_01/2017-01-01/FG/EI/ID/080300
